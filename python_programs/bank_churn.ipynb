# %%
import numpy as np
import pandas as pd
df = pd.read_csv('Churn_Modeling.csv')
df[df['Balance']>0].reset_index()
# Out:
#       index  RowNumber  CustomerId      Surname  CreditScore Geography  \
# 0         1          2    15647311         Hill          608     Spain
# 1         2          3    15619304         Onio          502    France
# 2         4          5    15737888     Mitchell          850     Spain
# 3         5          6    15574012          Chu          645     Spain
# 4         7          8    15656148       Obinna          376   Germany
# ...     ...        ...         ...          ...          ...       ...
# 6378   9991       9992    15769959  Ajuluchukwu          597    France
# 6379   9993       9994    15569266       Rahman          644    France
# 6380   9996       9997    15569892    Johnstone          516    France
# 6381   9998       9999    15682355    Sabbatini          772   Germany
# 6382   9999      10000    15628319       Walker          792    France
#
#       Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# ...
